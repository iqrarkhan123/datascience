# %% [markdown]
# # Fiverr project for practice

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("lavoro.csv")

# %% [markdown]
# ## Checklist for EDA:

# %%
# Q1: Check the different characteristics present in the dataset and their shape
data.head()
# Out:
#                 Location  \
# 0            Timor-Leste
# 1  Moldova (Republic of)
# 2    Palestine, State of
# 3                  Samoa
# 4                 Jordan
#
#    Employment to population ratio(% ages 15 and older) 2013  \
# 0                                               36.2
# 1                                               38.6
# 2                                               31.6
# 3                                                NaN
# 4                                               36.3
#
#    Labour force participation rate (% ages 15 and older) 2013  \
# 0                                               37.9
# 1                                               40.7
# 2                                               41.2
# 3                                               41.5
# 4                                               41.6
#
#    Employment in agriculture (% of total employment) 1990  \
# 0                                                NaN
# ...

# %%
data.tail()
# Out:
#     Location  Employment to population ratio(% ages 15 and older) 2013  \
# 218      NaN                                                NaN
# 219      NaN                                                NaN
# 220      NaN                                                NaN
# 221      NaN                                                NaN
# 222      NaN                                                NaN
#
#      Labour force participation rate (% ages 15 and older) 2013  \
# 218                                                NaN
# 219                                                NaN
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
#
#      Employment in agriculture (% of total employment) 1990  \
# 218                                                NaN
# 219                                                NaN
# 220                                                NaN
# ...

# %%
data.shape
# Out:
# (223, 15)

# %%
# q2: Check the data type of each column
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 15 columns):
# Location                                                      207 non-null object
# Employment to population ratio(% ages 15 and older) 2013      187 non-null float64
# Labour force participation rate (% ages 15 and older) 2013    194 non-null float64
# Employment in agriculture (% of total employment) 1990        72 non-null float64
# Employment in agriculture (% of total employment) 2012        155 non-null float64
# Employment in services (% of total employment) 1990           92 non-null float64
# Employment in services (% of total employment) 2012           155 non-null float64
# Labour force with tertiary education (%) 2007-2012            89 non-null float64
# Vulnerable employment (% of total employment) 2008-2013       142 non-null float64
# Total Unemployment (% of labour force) 2008-2013              178 non-null float64
# ...

# %%
# checking for missing values
data.isnull().sum()
# Out:
# Location                                                       16
# Employment to population ratio(% ages 15 and older) 2013       36
# Labour force participation rate (% ages 15 and older) 2013     29
# Employment in agriculture (% of total employment) 1990        151
# Employment in agriculture (% of total employment) 2012         68
# Employment in services (% of total employment) 1990           131
# Employment in services (% of total employment) 2012            68
# Labour force with tertiary education (%) 2007-2012            134
# Vulnerable employment (% of total employment) 2008-2013        81
# Total Unemployment (% of labour force) 2008-2013               45
# Long term Unemployment (% of labour force) 2008-2013          138
# Youth (% of youth labour force) 2008-2014                      54
# Youth not in school or employment (% ages 15Ð24) 2008-2013    140
# Output per worker (2011 PPP $) 2005-2012                       79
# ...

# %%
clean_data= data.fillna(0)

# %%
clean_data.isnull().sum()
# Out:
# Location                                                      0
# Employment to population ratio(% ages 15 and older) 2013      0
# Labour force participation rate (% ages 15 and older) 2013    0
# Employment in agriculture (% of total employment) 1990        0
# Employment in agriculture (% of total employment) 2012        0
# Employment in services (% of total employment) 1990           0
# Employment in services (% of total employment) 2012           0
# Labour force with tertiary education (%) 2007-2012            0
# Vulnerable employment (% of total employment) 2008-2013       0
# Total Unemployment (% of labour force) 2008-2013              0
# Long term Unemployment (% of labour force) 2008-2013          0
# Youth (% of youth labour force) 2008-2014                     0
# Youth not in school or employment (% ages 15Ð24) 2008-2013    0
# Output per worker (2011 PPP $) 2005-2012                      0
# Hours worked per week (per employed person) 2003-2012         0
# ...

# %%
clean_data.shape
# Out:
# (223, 15)

# %%
clean_data.columns
# Out:
# Index(['Location', 'Employment to population ratio(% ages 15 and older) 2013',
#        'Labour force participation rate (% ages 15 and older) 2013',
#        'Employment in agriculture (% of total employment) 1990',
#        'Employment in agriculture (% of total employment) 2012',
#        'Employment in services (% of total employment) 1990',
#        'Employment in services (% of total employment) 2012',
#        'Labour force with tertiary education (%) 2007-2012',
#        'Vulnerable employment (% of total employment) 2008-2013',
#        'Total Unemployment (% of labour force) 2008-2013',
#        'Long term Unemployment (% of labour force) 2008-2013',
#        'Youth (% of youth labour force) 2008-2014',
#        'Youth not in school or employment (% ages 15Ð24) 2008-2013',
#        'Output per worker (2011 PPP $) 2005-2012',
#        'Hours worked per week (per employed person) 2003-2012'],
#       dtype='object')

# %%
# descriptive summary of dataset
clean_data.describe()
# Out:
#        Employment to population ratio(% ages 15 and older) 2013  \
# count                                         223.000000
# mean                                           49.306726
# std                                            24.158368
# min                                             0.000000
# 25%                                            43.000000
# 50%                                            56.000000
# 75%                                            64.350000
# max                                            86.200000
#
#        Labour force participation rate (% ages 15 and older) 2013  \
# count                                         223.000000
# mean                                           55.581614
# std                                            23.645325
# min                                             0.000000
# 25%                                            53.100000
# 50%                                            62.000000
# ...

# %%
sns.countplot(clean_data["Location"].head(3))
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
clean_data.dtypes
# Out:
# Location                                                       object
# Employment to population ratio(% ages 15 and older) 2013      float64
# Labour force participation rate (% ages 15 and older) 2013    float64
# Employment in agriculture (% of total employment) 1990        float64
# Employment in agriculture (% of total employment) 2012        float64
# Employment in services (% of total employment) 1990           float64
# Employment in services (% of total employment) 2012           float64
# Labour force with tertiary education (%) 2007-2012            float64
# Vulnerable employment (% of total employment) 2008-2013       float64
# Total Unemployment (% of labour force) 2008-2013              float64
# Long term Unemployment (% of labour force) 2008-2013          float64
# Youth (% of youth labour force) 2008-2014                     float64
# Youth not in school or employment (% ages 15Ð24) 2008-2013    float64
# ...

# %%
clean_data.corr().head()
# Out:
#                                                     Employment to population ratio(% ages 15 and older) 2013  \
# Employment to population ratio(% ages 15 and ol...                                           1.000000
# Labour force participation rate (% ages 15 and ...                                           0.902765
# Employment in agriculture (% of total employmen...                                           0.165112
# Employment in agriculture (% of total employmen...                                           0.372483
# Employment in services (% of total employment) ...                                           0.150291
#
#                                                     Labour force participation rate (% ages 15 and older) 2013  \
# Employment to population ratio(% ages 15 and ol...                                           0.902765
# Labour force participation rate (% ages 15 and ...                                           1.000000
# ...

# %%
#Distribution chart for all columns this is for one columns all other are the same just change the column name
sns.displot(data=clean_data, x="Employment to population ratio(% ages 15 and older) 2013")

# %%
sns.boxplot(data=clean_data, x="Employment to population ratio(% ages 15 and older) 2013")

# %%
# after removing outliers
new=clean_data[clean_data["Employment to population ratio(% ages 15 and older) 2013"]>30] # remove outliers
sns.displot(data=new, x="Employment to population ratio(% ages 15 and older) 2013")

# %%
sns.displot(data=new, x="Employment to population ratio(% ages 15 and older) 2013", kind="kde")

# %%
# checking for abnormal you can check this one by one 
from matplotlib.pyplot import figure
sns.boxplot(data=clean_data)
figure(figsize=(50, 30))

# %%
sns.pairplot(clean_data)
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self._figure.tight_layout(*args, **kwargs)
