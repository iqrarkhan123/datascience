# %% [markdown]
# # Pandas Case Study
# Titanic dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic=sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# save the file in to csv
titanic.to_csv("kashti.csv")

# %%
# basic statistics and summary
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# drpoing columns from dataset axis=1 mean column and axis =0 mean rows
titanic_new=titanic.drop(["parch","embarked","deck","alone"],axis=1 )

# %%
titanic_new.head()
# Out:
#    survived  pclass     sex   age  sibsp     fare  class    who  adult_male  \
# 0         0       3    male  22.0      1   7.2500  Third    man        True
# 1         1       1  female  38.0      1  71.2833  First  woman       False
# 2         1       3  female  26.0      0   7.9250  Third  woman       False
# 3         1       1  female  35.0      1  53.1000  First  woman       False
# 4         0       3    male  35.0      0   8.0500  Third    man        True
#
#    embark_town alive
# 0  Southampton    no
# 1    Cherbourg   yes
# 2  Southampton   yes
# 3  Southampton   yes
# 4  Southampton    no

# %%
# convert data into dataframe
#df=pd.DataFrame([titanic_new])

# %%
titanic_new.mean()
# Out:
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# fare          32.204208
# adult_male     0.602694
# dtype: float64

# %%
titanic_new.groupby(["sex","class"]).mean()
# Out:
#                survived  pclass        age     sibsp        fare  adult_male
# sex    class
# female First   0.968085     1.0  34.611765  0.553191  106.125798    0.000000
#        Second  0.921053     2.0  28.722973  0.486842   21.970121    0.000000
#        Third   0.500000     3.0  21.750000  0.895833   16.118810    0.000000
# male   First   0.368852     1.0  41.281386  0.311475   67.226127    0.975410
#        Second  0.157407     2.0  30.740707  0.342593   19.741782    0.916667
#        Third   0.135447     3.0  26.507589  0.498559   12.661633    0.919308

# %%
# childeren that survived
titanic_new[titanic_new["age"]<18].groupby(["sex","class"]).mean()
# Out:
#                survived  pclass        age     sibsp        fare  adult_male
# sex    class
# female First   0.875000     1.0  14.125000  0.500000  104.083337    0.000000
#        Second  1.000000     2.0   8.333333  0.583333   26.241667    0.000000
#        Third   0.542857     3.0   8.428571  1.571429   18.727977    0.000000
# male   First   1.000000     1.0   8.230000  0.500000  116.072900    0.250000
#        Second  0.818182     2.0   4.757273  0.727273   25.659473    0.181818
#        Third   0.232558     3.0   9.963256  2.069767   22.752523    0.348837

# %%
# store sum column into variable and based on these coloum create a heatmap
scatter=titanic_new.loc[:,["survived","pclass","sibsp"]]
scatter.head()
# Out:
#    survived  pclass  sibsp
# 0         0       3      1
# 1         1       1      1
# 2         1       3      0
# 3         1       1      1
# 4         0       3      0

# %%
sns.heatmap(scatter.corr(),annot=True)
