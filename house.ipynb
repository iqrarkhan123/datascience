# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
house= pd.read_csv('All_Data.csv')
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house.isna().sum().sort_values(ascending=False)
# Out:
# PoolQC           2909
# MiscFeature      2814
# Alley            2721
# Fence            2348
# SalePrice        1459
# FireplaceQu      1420
# LotFrontage       486
# GarageYrBlt       159
# GarageFinish      159
# GarageQual        159
# GarageCond        159
# GarageType        157
# BsmtCond           82
# BsmtExposure       82
# BsmtQual           81
# BsmtFinType2       80
# BsmtFinType1       79
# MasVnrType         24
# MasVnrArea         23
# MSZoning            4
# BsmtHalfBath        2
# Functional          2
# Utilities           2
# BsmtFullBath        2
# Exterior1st         1
# Exterior2nd         1
# BsmtFinSF1          1
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
#                  ...
# LotShape            0
# MoSold              0
# Street              0
# LotArea             0
# YrSold              0
# MSSubClass          0
# RoofStyle           0
# ScreenPorch         0
# PoolArea            0
# HalfBath            0
# ...

# %%
house['SalePrice'].dropna()
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
# 5       143000.0
# 6       307000.0
# 7       200000.0
# 8       129900.0
# 9       118000.0
# 10      129500.0
# 11      345000.0
# 12      144000.0
# 13      279500.0
# 14      157000.0
# 15      132000.0
# 16      149000.0
# 17       90000.0
# 18      159000.0
# 19      139000.0
# 20      325300.0
# 21      139400.0
# 22      230000.0
# 23      129900.0
# 24      154000.0
# 25      256300.0
# 26      134800.0
# 27      306000.0
# 28      207500.0
# 29       68500.0
#           ...
# 1430    192140.0
# 1431    143750.0
# 1432     64500.0
# 1433    186500.0
# 1434    160000.0
# 1435    174000.0
# 1436    120500.0
# 1437    394617.0
# 1438    149700.0
# 1439    197000.0
# 1440    191000.0
# 1441    149300.0
# 1442    310000.0
# 1443    121000.0
# 1444    179600.0
# 1445    129000.0
# 1446    157900.0
# 1447    240000.0
# 1448    112000.0
# 1449     92000.0
# 1450    136000.0
# ...

# %%
house.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
# Street              0
# Alley            2721
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         24
# MasVnrArea         23
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         1
# TotRmsAbvGrd        0
# Functional          2
# Fireplaces          0
# FireplaceQu      1420
# GarageType        157
# GarageYrBlt       159
# GarageFinish      159
# ...

# %%
house['SalePrice'].isna().sum()
# Out:
# 1459

# %%
(house['TotalBsmtSF'] - (house['BsmtFinSF1'] + house['BsmtFinSF2'] + house['BsmtUnfSF'])).describe()
# Out:
# count    2918.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# dtype: float64

# %%
house.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu'],axis=True).head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
house.drop(columns='TotalBsmtSF', inplace=True)

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(house.corr().abs() > 0.75)

# %%
house.corr().loc[['TotRmsAbvGrd', 'GrLivArea', 'GarageCars', 'GarageArea'], ['TotRmsAbvGrd', 'GrLivArea', 'GarageCars', 'GarageArea']]
# Out:
#               TotRmsAbvGrd  GrLivArea  GarageCars  GarageArea
# TotRmsAbvGrd      1.000000   0.808354    0.358053    0.328687
# GrLivArea         0.808354   1.000000    0.489933    0.485469
# GarageCars        0.358053   0.489933    1.000000    0.889700
# GarageArea        0.328687   0.485469    0.889700    1.000000

# %%
house.drop(columns=['TotRmsAbvGrd', 'GarageCars'], inplace=True)

# %%
df = house.loc.join()
for col in (df):
    print(df.groupby(col)['SalePrice'].agg(['mean', 'count']).sort_values('mean'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-dad8e8b84a76> in <module>
# ----> 1 df = house.loc.join()
#       2 for col in (df):
#       3     print(df.groupby(col)['SalePrice'].agg(['mean', 'count']).sort_values('mean'))
#
# AttributeError: '_LocIndexer' object has no attribute 'join'

# %%
to_drop = ['MSZoning', 'Street', 'LandContour', 'Utilities',
           'LotConfig', 'Condition1', 'Condition2', 'BldgType', 'RoofStyle',
           'RoofMatl', 'Heating', 'Electrical', 'PavedDrive',
           'SaleType', 'SaleCondition']
house.drop(columns=to_drop, inplace=True)

# %%
house.corr().loc['SalePrice'].sort_values()
# Out:
# KitchenAbvGr    -0.135907
# EnclosedPorch   -0.128578
# MSSubClass      -0.084284
# OverallCond     -0.077856
# YrSold          -0.028923
# LowQualFinSF    -0.025606
# Id              -0.021917
# MiscVal         -0.021190
# BsmtHalfBath    -0.016844
# BsmtFinSF2      -0.011378
# 3SsnPorch        0.044584
# MoSold           0.046432
# PoolArea         0.092404
# ScreenPorch      0.111447
# BedroomAbvGr     0.168213
# BsmtUnfSF        0.214479
# BsmtFullBath     0.227122
# LotArea          0.263843
# HalfBath         0.284108
# OpenPorchSF      0.315856
# 2ndFlrSF         0.319334
# WoodDeckSF       0.324413
# LotFrontage      0.351799
# BsmtFinSF1       0.386420
# Fireplaces       0.466929
# MasVnrArea       0.477493
# GarageYrBlt      0.486362
# YearRemodAdd     0.507101
# YearBuilt        0.522897
# FullBath         0.560664
# 1stFlrSF         0.605852
# GarageArea       0.623431
# GrLivArea        0.708624
# OverallQual      0.790982
# SalePrice        1.000000
# ...

# %%
to_keep = ['YearBuilt', 'YearRemodAdd', 'GarageFinish', 'FullBath',
 '1stFlrSF', 'GarageArea', 'BsmtQual', 'KitchenQual', 'ExterQual', 'GrLivArea', 'OverallQual']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-629dadf283d5> in <module>
#       1 to_keep = ['YearBuilt', 'YearRemodAdd', 'GarageFinish', 'FullBath', '1stFlrSF', 'GarageArea', 'BsmtQual', 'KitchenQual', 'ExterQual', 'GrLivArea', 'OverallQual']
# ----> 2 to_drop = (house).difference(to_keep)
#       3 df.drop(columns=to_drop, inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'difference'

# %%
house.to_csv('all-data.csv')

# %%
fea=pd.read_csv('trains.csv')

# %%
fea.head()
# Out:
#    Id  MSSubClass Neighborhood  OverallQual  OverallCond  YearBuilt  \
# 0   1          60      CollgCr            7            5       2003
# 1   2          20      Veenker            6            8       1976
# 2   3          60      CollgCr            7            5       2001
# 3   4          70      Crawfor            7            5       1915
# 4   5          60      NoRidge            8            5       2000
#
#    YearRemodAdd ExterQual BsmtQual  1stFlrSF  GrLivArea  FullBath  \
# 0          2003        Gd       Gd       856       1710         2
# 1          1976        TA       Gd      1262       1262         2
# 2          2002        Gd       Gd       920       1786         2
# 3          1970        TA       TA       961       1717         1
# 4          2000        Gd       Gd      1145       2198         2
#
#    KitchenAbvGr KitchenQual GarageFinish  GarageArea  EnclosedPorch  YrSold  \
# 0             1          Gd          RFn         548              0    2008
# ...

# %%
fea.corr().loc['SalePrice'].sort_values()
# Out:
# KitchenAbvGr    -0.135907
# EnclosedPorch   -0.128578
# MSSubClass      -0.084284
# OverallCond     -0.077856
# YrSold          -0.028923
# Id              -0.021917
# YearRemodAdd     0.507101
# YearBuilt        0.522897
# FullBath         0.560664
# 1stFlrSF         0.605852
# TotalBsmtSF      0.613581
# GarageArea       0.623431
# GarageCars       0.640409
# GrLivArea        0.708624
# OverallQual      0.790982
# SalePrice        1.000000
# Name: SalePrice, dtype: float64

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
train=pd.read_csv('train.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.corr().loc['SalePrice'].sort_values()
# Out:
# KitchenAbvGr    -0.135907
# EnclosedPorch   -0.128578
# MSSubClass      -0.084284
# OverallCond     -0.077856
# YrSold          -0.028923
# LowQualFinSF    -0.025606
# Id              -0.021917
# MiscVal         -0.021190
# BsmtHalfBath    -0.016844
# BsmtFinSF2      -0.011378
# 3SsnPorch        0.044584
# MoSold           0.046432
# PoolArea         0.092404
# ScreenPorch      0.111447
# BedroomAbvGr     0.168213
# BsmtUnfSF        0.214479
# BsmtFullBath     0.227122
# LotArea          0.263843
# HalfBath         0.284108
# OpenPorchSF      0.315856
# 2ndFlrSF         0.319334
# WoodDeckSF       0.324413
# LotFrontage      0.351799
# BsmtFinSF1       0.386420
# Fireplaces       0.466929
# MasVnrArea       0.477493
# GarageYrBlt      0.486362
# YearRemodAdd     0.507101
# YearBuilt        0.522897
# TotRmsAbvGrd     0.533723
# FullBath         0.560664
# 1stFlrSF         0.605852
# TotalBsmtSF      0.613581
# GarageArea       0.623431
# GarageCars       0.640409
# ...

# %%
train.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# LotFrontage       259
# GarageCond         81
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageQual         81
# BsmtExposure       38
# BsmtFinType2       38
# BsmtFinType1       37
# BsmtCond           37
# BsmtQual           37
# MasVnrArea          8
# MasVnrType          8
# HeatingQC           1
# Electrical          1
# YearRemodAdd        0
# MSSubClass          0
# Foundation          0
# ExterCond           0
# ExterQual           0
# Exterior2nd         0
# Exterior1st         0
# RoofMatl            0
# RoofStyle           0
# Utilities           0
#                  ...
# GarageArea          0
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# 3SsnPorch           0
# BsmtUnfSF           0
# ScreenPorch         0
# PoolArea            0
# MiscVal             0
# MoSold              0
# ...

# %%
train.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu'],axis=True).head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
sns.histplot(train['SalePrice'])

# %%
train.to_csv('train.csv')
